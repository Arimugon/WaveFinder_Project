# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup as bs
import re
import json
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import csv
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None) 
from selenium import webdriver
import time

# %%
# %pip install webdriver-manager
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\ari\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: tqdm in c:\users\ari\anaconda3\lib\site-packages (from webdriver-manager) (4.64.0)
# Requirement already satisfied: requests in c:\users\ari\anaconda3\lib\site-packages (from webdriver-manager) (2.27.1)
# Requirement already satisfied: python-dotenv in c:\users\ari\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ari\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ari\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ari\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ari\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\ari\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
PATH=ChromeDriverManager().install()   

driver=webdriver.Chrome(PATH)

# %%
url = 'https://www.windguru.cz/48686'
driver=webdriver.Chrome(PATH)
driver.get(url)
time.sleep(5)

# %%
date=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_dates"]').text.split()

# %%
#len(date)

# %%
lst=[]
for e in range(0,len(date)+3,3):
    var=''.join(date[e-2]).replace('.','')
    lst.append(var)
    

lst
# Out:
# ['18',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '10',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '18',
#  '18']

# %%
date=lst
date.pop(0)
# Out:
# '18.'

# %%
date

removed_chars = ['.']

chars = set(removed_chars)
    res = ''.join(filter(lambda x: x not in chars, s))

# %%
lst
# Out:
# ['',
#  '8.09h',
#  '8.15h',
#  '8.21h',
#  '9.07h',
#  '9.13h',
#  '9.19h',
#  '10.05h',
#  '10.11h',
#  '10.17h',
#  '11.03h',
#  '11.09h',
#  '11.15h',
#  '11.22h',
#  '12.08h',
#  '12.14h',
#  '12.20h',
#  '13.06h',
#  '13.12h',
#  '13.18h',
#  '14.04h',
#  '14.13h',
#  '14.22h',
#  '15.10h',
#  '15.19h',
#  '16.07h',
#  '16.16h',
#  '17.04h',
#  '17.13h',
#  '17.22h']

# %%
playa=driver.find_element(By.XPATH, '//*[@id="forecasts-page-content"]/div[2]/div[1]/a[1]/div').text.split()[2]
playa
# Out:
# 'Hondarribia'

# %%
velocidad=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_WINDSPD"]').text.split()
rafagas=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_GUST"]').text.split()
ola=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_HTSGW"]').text.split()
temp=driver.find_element(By.XPATH, '//*[@id="tabid_0_0_TMP"]').text.split()

# %%
def direc_viento(url):
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    time.sleep(2)
    tabla=driver.find_element(By.XPATH,'//*[@id="tabid_0_content_div"]/table/tbody')
    filas=tabla.find_elements(By.XPATH, '//*[@id="tabid_0_0_SMER"]')
    data=[]
    for f in filas:
        elementos=f.find_elements(By.TAG_NAME, 'span')
        tmp=[]
        for e in elementos:
            tmp.append(e.get_attribute('title'))
        tmp.append(url.split('/')[-1])  # nombre del equipo
        data.append(tmp)
        
    return data

# %%
direc_viento=direc_viento('https://www.windguru.cz/48686')

# %%
direc_viento
# Out:
# [['E (79.39129724299045°)',
#   'E (85.73099930940766°)',
#   'ESE (120.78065063389614°)',
#   'E (90.04476374360578°)',
#   'E (88.43727763270654°)',
#   'ENE (78.48338335589159°)',
#   'SSE (148.88091849860797°)',
#   'SO (217.14172371450772°)',
#   'SO (235.01318205557027°)',
#   'SO (234.9452510255946°)',
#   'OSO (248.09784447123462°)',
#   'NO (319.5090376767446°)',
#   'NNE (13.198930512677325°)',
#   'NE (41.105645627452844°)',
#   'NNE (32.75043559623299°)',
#   'NNE (33.27582425329076°)',
#   'NE (49.255575271647444°)',
#   'N (9.511016662180495°)',
#   'N (9.79861513183053°)',
#   'N (9.319901310159906°)',
#   'ENE (56.96384421237314°)',
#   'ENE (67.36817648617388°)',
#   'ENE (73.80003450215312°)',
#   'ENE (64.40944024565347°)',
#   'ESE (104.85135124221588°)',
#   'SE (140.17011754930317°)',
#   'SE (141.13728521816515°)',
#   'OSO (237.86045409944808°)',
#   'OSO (239.9859094966949°)',
#   'O (268.1768902975237°)',
#   'SE (138.8791371283643°)',
#   'SSE (151.2168525245564°)',
#   'ENE (59.163597208867266°)',
#   'NE (43.77001542199647°)',
#   'SSE (163.20495062113255°)',
#   'SSO (198.45935388329852°)',
#   'ESE (107.80000326689661°)',
#   'ESE (118.90241622556368°)',
#   'SSE (146.42811921598297°)',
#   'SSE (161.7762101397469°)',
#   'SSE (156.14290502407178°)',
#   'ESE (104.75311029256406°)',
#   'E (90.92495942522658°)',
#   'E (88.22403646579747°)',
#   'E (97.676567767309°)',
#   'E (96.0501339278454°)',
#   'S (174.0616278869283°)',
#   'ESE (120.15084481847273°)',
#   'ESE (113.29075317701046°)',
#   'E (88.42414217894977°)',
#   'E (81.96320087272295°)',
#   'ENE (74.17456718069984°)',
#   'E (81.55469986081303°)',
#   'ENE (77.16409960874473°)',
#   'E (85.57810396219773°)',
#   'E (81.2550064033048°)',
#   'ESE (110.32848988723003°)',
#   'SE (126.56207215176815°)',
#   'NE (45.756170716602924°)',
#   'E (97.37789551291262°)',
#   'ENE (69.11315451461668°)',
#   'ENE (76.71825780435786°)',
#   'E (89.31479634171107°)',
#   'E (86.7986410197059°)',
#   'SE (130.73604930344746°)',
#   'SE (133.63190819949756°)',
#   'SE (125.28187540717991°)',
#   'S (188.25429191533797°)',
#   'OSO (255.95725613156327°)',
#   'NNO (330.9606180588597°)',
#   'N (352.2751575213655°)',
#   'NNO (342.9204986093345°)',
#   'N (0.2970439741254383°)',
#   'ESE (111.97530793723716°)',
#   'E (85.20997073911077°)',
#   'ESE (110.19198512691408°)',
#   'SSE (158.9222854496931°)',
#   'SSO (207.30572472775157°)',
#   'SO (235.75053975016374°)',
#   'SO (235.934173325579°)',
#   'SSO (212.17844632602575°)',
#   'SSO (193.87922194814792°)',
#   'NE (46.55847355640379°)',
#   'E (89.78991226540003°)',
#   'E (93.3079859428385°)',
#   'E (93°)',
#   'ESE (104.00000000000001°)',
#   '48686']]

# %%
def direc_ola(url):
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    time.sleep(2)
    tabla=driver.find_element(By.XPATH,'//*[@id="tabid_0_content_div"]/table/tbody')
    filas=tabla.find_elements(By.XPATH, '//*[@id="tabid_0_0_DIRPW"]')
    data=[]
    for f in filas:
        elementos=f.find_elements(By.TAG_NAME, 'span')
        tmp=[]
        for e in elementos:
            tmp.append(e.get_attribute('title'))
        tmp.append(url.split('/')[-1])  # nombre del equipo
        data.append(tmp)
    return data

# %%
direc_ola=direc_ola('https://www.windguru.cz/48686')

# %%
direc_ola
# Out:
# [['N (2°)',
#   'N (2°)',
#   'N (356°)',
#   'N (356°)',
#   'N (356°)',
#   'N (358°)',
#   'N (357°)',
#   'ENE (70°)',
#   'N (3°)',
#   'N (2°)',
#   'N (5°)',
#   'N (3°)',
#   'OSO (250°)',
#   'O (268°)',
#   'N (1°)',
#   'N (2°)',
#   'N (359°)',
#   'N (355°)',
#   'N (352°)',
#   'N (353°)',
#   'N (351°)',
#   'N (352°)',
#   'N (353°)',
#   'N (353°)',
#   'N (354°)',
#   'N (353°)',
#   'N (352°)',
#   'N (353°)',
#   'N (352°)',
#   'N (351°)',
#   'NO (322°)',
#   'NO (320°)',
#   'NO (312°)',
#   'NO (311.3333333333333°)',
#   'NO (312°)',
#   'NO (314°)',
#   'NO (316°)',
#   'NO (317.66666666666663°)',
#   'NO (319°)',
#   'NO (318°)',
#   'ONO (285°)',
#   'ONO (285.66666666666663°)',
#   'ONO (286°)',
#   'ONO (286°)',
#   'ONO (284.66666666666663°)',
#   'ONO (284°)',
#   'ONO (284°)',
#   'ONO (282.66666666666663°)',
#   'ONO (282.3333333333333°)',
#   'ONO (283°)',
#   'ONO (282°)',
#   'ONO (282°)',
#   'ONO (282.3333333333333°)',
#   'ONO (283°)',
#   'ONO (281.66666666666663°)',
#   'ONO (281.3333333333333°)',
#   'ONO (282°)',
#   'O (280.66666666666663°)',
#   'O (280.3333333333333°)',
#   'O (281°)',
#   'O (280°)',
#   'O (280°)',
#   'O (281°)',
#   'ONO (284°)',
#   'ONO (284°)',
#   'ONO (283°)',
#   'ONO (288°)',
#   'ONO (287°)',
#   'ONO (286°)',
#   'ONO (286°)',
#   'ONO (286°)',
#   'ONO (285°)',
#   'ONO (285°)',
#   'ONO (284°)',
#   'ONO (282°)',
#   'ONO (283°)',
#   'ONO (282°)',
#   'O (281°)',
#   'O (281°)',
#   'ONO (288°)',
#   'ONO (292°)',
#   'NO (316°)',
#   'NNO (331°)',
#   'O (281°)',
#   'O (281°)',
#   'O (281°)',
#   'ONO (290°)',
#   'ONO (292°)',
#   '48686']]

# %%
df=pd.DataFrame(columns=['Wave_direc','Wave'])

# %%
for e in range(len(direc_ola)):
    df['Wave_direc']=direc_ola[e]

# %%
df
# Out:
#                    Wave_direc Wave
# 0                      N (2°)  NaN
# 1                      N (2°)  NaN
# 2                    N (356°)  NaN
# 3                    N (356°)  NaN
# 4                    N (356°)  NaN
# 5                    N (358°)  NaN
# 6                    N (357°)  NaN
# 7                   ENE (70°)  NaN
# 8                      N (3°)  NaN
# 9                      N (2°)  NaN
# 10                     N (5°)  NaN
# 11                     N (3°)  NaN
# 12                 OSO (250°)  NaN
# 13                   O (268°)  NaN
# 14                     N (1°)  NaN
# 15                     N (2°)  NaN
# 16                   N (359°)  NaN
# 17                   N (355°)  NaN
# 18                   N (352°)  NaN
# 19                   N (353°)  NaN
# 20                   N (351°)  NaN
# 21                   N (352°)  NaN
# 22                   N (353°)  NaN
# 23                   N (353°)  NaN
# 24                   N (354°)  NaN
# 25                   N (353°)  NaN
# 26                   N (352°)  NaN
# 27                   N (353°)  NaN
# 28                   N (352°)  NaN
# 29                   N (351°)  NaN
# 30                  NO (322°)  NaN
# 31                  NO (320°)  NaN
# 32                  NO (312°)  NaN
# 33    NO (311.3333333333333°)  NaN
# 34                  NO (312°)  NaN
# 35                  NO (314°)  NaN
# 36                  NO (316°)  NaN
# 37   NO (317.66666666666663°)  NaN
# 38                  NO (319°)  NaN
# 39                  NO (318°)  NaN
# 40                 ONO (285°)  NaN
# 41  ONO (285.66666666666663°)  NaN
# 42                 ONO (286°)  NaN
# 43                 ONO (286°)  NaN
# 44  ONO (284.66666666666663°)  NaN
# 45                 ONO (284°)  NaN
# 46                 ONO (284°)  NaN
# 47  ONO (282.66666666666663°)  NaN
# 48   ONO (282.3333333333333°)  NaN
# 49                 ONO (283°)  NaN
# 50                 ONO (282°)  NaN
# 51                 ONO (282°)  NaN
# 52   ONO (282.3333333333333°)  NaN
# 53                 ONO (283°)  NaN
# 54  ONO (281.66666666666663°)  NaN
# 55   ONO (281.3333333333333°)  NaN
# 56                 ONO (282°)  NaN
# 57    O (280.66666666666663°)  NaN
# 58     O (280.3333333333333°)  NaN
# 59                   O (281°)  NaN
# 60                   O (280°)  NaN
# 61                   O (280°)  NaN
# 62                   O (281°)  NaN
# 63                 ONO (284°)  NaN
# 64                 ONO (284°)  NaN
# 65                 ONO (283°)  NaN
# 66                 ONO (288°)  NaN
# 67                 ONO (287°)  NaN
# 68                 ONO (286°)  NaN
# 69                 ONO (286°)  NaN
# 70                 ONO (286°)  NaN
# 71                 ONO (285°)  NaN
# 72                 ONO (285°)  NaN
# 73                 ONO (284°)  NaN
# 74                 ONO (282°)  NaN
# 75                 ONO (283°)  NaN
# 76                 ONO (282°)  NaN
# 77                   O (281°)  NaN
# 78                   O (281°)  NaN
# 79                 ONO (288°)  NaN
# 80                 ONO (292°)  NaN
# 81                  NO (316°)  NaN
# 82                 NNO (331°)  NaN
# 83                   O (281°)  NaN
# 84                   O (281°)  NaN
# 85                   O (281°)  NaN
# 86                 ONO (290°)  NaN
# 87                 ONO (292°)  NaN
# 88                      48686  NaN

# %%
extraer('https://www.windguru.cz/48686')
# Out:
#               0           1                    2             3   \
# 0     J\n8.\n07h  J\n8.\n09h           J\n8.\n11h    J\n8.\n13h
# 1              3           3                    7             5
# 2              5           5                   11            10
# 3
# 4            0.6         0.6                  0.5           0.5
# 5              6           6                   11            11
# 6
# 7             10          11                   12            12
# 8           2.1k        2.1k                   2k          2.2k
# 9     83\n84\n11  92\n100\n5          98\n100\n35  100\n100\n43
# 10                                                          0.7
# 11
# 12  16:45\n10:20       04:55  04:55\n17:15\n10:55         05:25
#
#                      4            5                    6           7   \
# 0            J\n8.\n15h   J\n8.\n17h           J\n8.\n19h  J\n8.\n21h
# 1                     7            8                    5           6
# 2                    11           14                   13          13
# 3
# 4                   0.5          0.6                  0.6         0.5
# 5                     6           11                   10           6
# 6
# 7                    12           11                   12          14
# 8                  2.3k         2.3k                 2.3k        2.3k
# 9           99\n100\n81  86\n100\n49           70\n89\n78  99\n95\n60
# 10                  1.2          0.5                  0.3
# 11
# 12  05:25\n17:50\n11:35               06:00\n18:20\n12:15
#
#              8                    9           10                   11  \
# 0    V\n9.\n03h           V\n9.\n05h  V\n9.\n07h           V\n9.\n09h
# 1             7                    7           9                    6
# 2            15                   13          16                   13
# 3
# 4           0.5                  0.6         0.7                  0.7
# 5             5                    3           4                    4
# 6
# 7            14                   14          13                   12
# 8          2.2k                 2.1k          2k                   2k
# 9   100\n54\n34           83\n92\n54  85\n99\n98           71\n98\n98
# 10                                           0.1                  0.9
# 11
# 12        06:35  06:35\n18:55\n12:55              07:10\n19:35\n13:35
#
#             12                   13          14                   15  \
# 0   V\n9.\n11h           V\n9.\n13h  V\n9.\n15h           V\n9.\n17h
# 1            5                    5           5                    7
# 2           10                    7           8                   11
# 3
# 4          0.7                  0.7         0.7                  0.8
# 5            4                    6           6                    6
# 6
# 7           12                   12          12                   12
# 8         2.1k                   2k          2k                 1.9k
# 9   73\n89\n94           93\n68\n97  93\n91\n95           96\n98\n98
# 10                                                               0.2
# 11
# 12       01:45  07:55\n20:25\n14:20       02:30  08:40\n21:20\n15:15
#
#              16                   17           18            19           20  \
# 0    V\n9.\n19h           V\n9.\n21h  S\n10.\n03h   S\n10.\n05h  S\n10.\n07h
# 1             8                    8            7             7            7
# 2            12                   12           11            11           11
# 3
# 4           0.9                    1          1.1           1.1            1
# 5             6                    6            6             6            6
# 6
# 7            11                   10            7             6            7
# 8          1.9k                 1.7k          960           810          810
# 9   100\n99\n99         100\n100\n98   44\n44\n83    22\n40\n79        8\n76
# 10          0.2                  0.7          0.1
# 11
# 12        03:30  09:40\n22:25\n16:15        04:35  10:45\n17:20        05:40
#
#              21           22           23           24           25  \
# 0   S\n10.\n09h  S\n10.\n11h  S\n10.\n13h  S\n10.\n15h  S\n10.\n17h
# 1             7            6            4            4            4
# 2            10            8            7            7            6
# 3
# 4             1          0.9          0.8          0.7          0.7
# 5             6            6            6            6            5
# 6
# 7             6            6            7            7            7
# 8           790          800          810          850          890
# 9            62           60           45           32        6\n33
# 10
# 11
# 12        05:40        48686         None         None         None
#
#              26           27           28           29           30  \
# 0   S\n10.\n19h  S\n10.\n21h  D\n11.\n03h  D\n11.\n05h  D\n11.\n07h
# 1             4            4            7            6            7
# 2             6            6           12           10           10
# 3
# 4           0.6          0.5          0.5          0.9          1.1
# 5             5            5            8            4            5
# 6
# 7             6            6            6            6            7
# 8           940           1k         1.1k         1.1k         1.1k
# 9    28\n24\n41   14\n14\n27   69\n37\n47   86\n45\n62   79\n58\n46
# 10                       0.2          0.1          0.2
# 11
# 12         None         None         None         None         None
#
#              31           32           33           34           35  \
# 0   D\n11.\n09h  D\n11.\n11h  D\n11.\n13h  D\n11.\n15h  D\n11.\n17h
# 1             6            5            4            4            4
# 2             9            7            6            6            5
# 3
# 4             1            1            1            1          0.9
# 5             5            5            7            6            6
# 6
# 7             7            7            8            8            8
# 8          1.2k         1.2k         1.2k         1.1k         1.1k
# 9    53\n76\n30    8\n50\n31    30\n68\n     72\n51\n    89\n56\n24
# 10
# 11
# 12         None         None         None         None         None
#
#              36           37           38           39           40  \
# 0   D\n11.\n19h  D\n11.\n22h  L\n12.\n04h  L\n12.\n06h  L\n12.\n08h
# 1             4            5            3            4            4
# 2             5            8            4            3            4
# 3
# 4           0.8          0.7          0.4          0.4          0.4
# 5             6            5           22           22           21
# 6
# 7             7            7            6            4            4
# 8          1.2k         1.2k         1.2k         1.1k         1.2k
# 9    83\n63\n24                44\n47\n21    56\n43\n8    86\n48\n
# 10
# 11
# 12         None         None         None         None         None
#
#              41           42           43           44           45  \
# 0   L\n12.\n10h  L\n12.\n12h  L\n12.\n14h  L\n12.\n16h  L\n12.\n18h
# 1             3            5            6            8            8
# 2             4            6            9           13           14
# 3
# 4           0.4          0.4          0.5          0.5          0.6
# 5            21           20           20           20           19
# 6
# 7             6            8            9            9            8
# 8          1.3k         1.4k         1.5k         1.8k         1.9k
# 9     85\n48\n   100\n93\n11   80\n87\n16   81\n87\n16  100\n98\n27
# 10                                    0.2          0.2
# 11
# 12         None         None         None         None         None
#
#              46            47           48           49           50  \
# 0   L\n12.\n20h   L\n12.\n22h  M\n13.\n04h  M\n13.\n06h  M\n13.\n08h
# 1             8             4            5            6            7
# 2            13             7            8            8           10
# 3
# 4           0.6           0.6          0.7          0.8          0.8
# 5            18            18           17           16           16
# 6
# 7             9             9            9            8            8
# 8            2k          1.8k           2k         2.4k         2.4k
# 9   96\n100\n62  100\n100\n88  100\n86\n90  100\n84\n93   90\n90\n77
# 10          0.2           0.4          0.3          0.1
# 11
# 12         None          None         None         None         None
#
#              51           52           53           54           55  \
# 0   M\n13.\n10h  M\n13.\n12h  M\n13.\n14h  M\n13.\n16h  M\n13.\n18h
# 1             6            5            5            5            5
# 2             9            7            7            7            6
# 3
# 4           0.9          0.8          0.8          0.9          0.8
# 5            16           16           15           15           15
# 6
# 7             8           10           11           10           10
# 8          2.5k         2.5k         2.5k         2.5k         2.5k
# 9   100\n68\n78   99\n40\n81   91\n79\n81   93\n83\n82   82\n87\n86
# 10
# 11
# 12         None         None         None         None         None
#
#              56           57           58           59           60  \
# 0   M\n13.\n20h  M\n13.\n22h  X\n14.\n04h  X\n14.\n07h  X\n14.\n10h
# 1             5            6            7            9            7
# 2             6            9           11           13           11
# 3
# 4           0.8          0.8          0.6          0.7          0.8
# 5            15           15           14           14           13
# 6
# 7            10           10           10            9            9
# 8          2.5k         2.3k         2.2k         2.2k         2.2k
# 9    85\n97\n88   65\n93\n73   73\n65\n68  100\n78\n93   68\n93\n98
# 10          0.1          0.2          0.3          0.7          0.7
# 11
# 12         None         None         None         None         None
#
#              61           62           63           64           65  \
# 0   X\n14.\n13h  X\n14.\n16h  X\n14.\n19h  X\n14.\n22h  J\n15.\n04h
# 1             6            7            7            7            4
# 2            10            9            9           10            9
# 3
# 4           0.8          0.8          0.9            1          1.2
# 5            13           13           13            6            7
# 6
# 7            10           11           10            9           11
# 8          2.2k         2.1k         2.1k         2.1k           2k
# 9    68\n95\n98   52\n79\n84   68\n75\n82   51\n38\n77   68\n54\n55
# 10          0.3                                    0.1
# 11
# 12         None         None         None         None         None
#
#              66           67           68           69           70  \
# 0   J\n15.\n07h  J\n15.\n10h  J\n15.\n13h  J\n15.\n16h  J\n15.\n19h
# 1             7            5            9            8           12
# 2            10            9           19            7           14
# 3
# 4           1.4          1.6          1.8          1.9          2.3
# 5             7            8            8            8            8
# 6
# 7            11           11           12           11            8
# 8            2k         1.7k         1.7k         1.2k          990
# 9    68\n68\n50   36\n68\n66       29\n50     100\n100     100\n100
# 10                       0.1                                    0.2
# 11
# 12         None         None         None         None         None
#
#              71           72           73           74           75  \
# 0   J\n15.\n22h  V\n16.\n04h  V\n16.\n07h  V\n16.\n10h  V\n16.\n13h
# 1            13           16           13            6            3
# 2            18           18           17            8            4
# 3
# 4           2.7          2.5          2.3          1.9          1.5
# 5             8            8            7            8           14
# 6
# 7             8            9            9            7            7
# 8           610          820         1.2k          600           1k
# 9      100\n100      70\n100          100          100          100
# 10          0.4                                    0.1          0.4
# 11
# 12         None         None         None         None         None
#
#              76           77           78           79           80  \
# 0   V\n16.\n16h  V\n16.\n19h  V\n16.\n22h  S\n17.\n04h  S\n17.\n07h
# 1             2            4            6           10            9
# 2             2            3            8           14           12
# 3
# 4           1.3          1.1            1          1.3          1.3
# 5            14           13           13           13           12
# 6
# 7             8            8            8            9            9
# 8           790         1.1k           1k         1.2k         1.4k
# 9            78           22        5\n88          100     48\n 100
# 10
# 11
# 12         None         None         None         None         None
#
#              81           82           83           84           85  \
# 0   S\n17.\n10h  S\n17.\n13h  S\n17.\n16h  S\n17.\n19h  S\n17.\n22h
# 1             6            3            5            6            8
# 2             9            8            7            9           13
# 3
# 4           1.1            1          0.9          0.9            1
# 5            12           12           12           11           11
# 6
# 7            10           11           11            9            8
# 8          1.2k         1.5k         1.3k         1.5k         1.4k
# 9       99\n 90    35\n5\n48     26\n5\n5      76\n 10    70\n52\n
# 10                                                 0.8          0.6
# 11
# 12         None         None         None         None         None
#
#              86           87     88
# 0   D\n18.\n04h  D\n18.\n07h  48686
# 1            10            9  48686
# 2            20           18  48686
# 3                             48686
# 4             1          0.9  48686
# 5             4            4  48686
# 6                             48686
# 7             6            7  48686
# 8          2.3k         2.3k  48686
# 9     28\n87\n       100\n89  48686
# 10                            48686
# 11                            48686
# 12         None         None   None

# %%
loca=driver.find_element(By.XPATH, '//*[@id="forecasts-page-content"]/div[2]/div[2]/ul/li[4]/a').text[:-8]
loca
# Out:
# 'lat: 43.38, lon: -1.79, '

# %%
localizacion=loca[:-8]
localizacion
# Out:
# 'lat: 43.38, lon: -1.79, '
